# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Moataz-Elzuhery/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# Lane 2 — Refresh / Content Opportunity Scoring.
# I chose this lane because it connects the data to a clear content decision: which pages should be reviewed first. The goal is not to predict whether a page will definitely recover after a refresh, but to use observable search and engagement signals to prioritize pages for human review. This lane is also a good fit for the starter dataset because it contains impressions, clicks, sessions, position, CTR, content age, freshness, and trend signals.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# Decision: Which content pages should be reviewed first for refresh, improvement, protection, or monitoring?
#
# Action: A content or SEO reviewer could use the ranked list to decide which pages deserve attention first, based on their search visibility, recent movement, age, CTR, and engagement signals.
#
# Cost of a wrong call: A false positive could waste limited review and content resources on a page that does not need attention. A false negative could cause the team to miss a page with a meaningful opportunity or problem.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The starter dataset contains 30,000 pages and 156,010,989 total impressions over the last 90 days. There are 16,262 pages with a declining trend, which shows that there is a meaningful group of pages that could be considered for further review.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/Moataz-Elzuhery/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Number of rows:", len(df))
print("Total 90d impressions:", df["impressions_90d"].sum())
print("Pages with declining trend:", (df["trend_direction"] == "down").sum())
# Out:
# Number of rows: 30000
# Total 90d impressions: 156010989
# Pages with declining trend: 16262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This project can identify observed patterns in the starter data and provide directional decision support for content review. It can measure relationships between content signals and observed performance.
#
# It cannot prove that refreshing a page will cause traffic or clicks to recover, and it cannot predict Google's algorithm or guarantee future performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
